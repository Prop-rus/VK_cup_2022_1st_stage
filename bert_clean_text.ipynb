# %%
import pandas as pd
import torch
import numpy as np
from transformers import BertTokenizer, BertModel
from torch import nn
from torch.optim import Adam
from tqdm import tqdm

import nltk

import string
import re
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('russian')
# Out:
# /home/prop/anaconda3/envs/torch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
datapath = f'train.csv'
df = pd.read_csv(datapath)
df.head()
# Out:
#          oid      category                                               text
# 0  365271984  winter_sport  Волшебные фото Виктория Поплавская ЕвгенияМедв...
# 1  503385563       extreme  Возвращение в подземелье Треша 33 Эйфория тупо...
# 2  146016084      football  Лучшие чешские вратари – Доминик Доминатор Гаш...
# 3  933865449    boardgames  Rtokenoid Warhammer40k валрак решил нас подкор...
# 4  713550145        hockey  Шестеркин затаскивает Рейнджерс в финал Восточ...

# %%
tokenizer = BertTokenizer.from_pretrained('DeepPavlov/rubert-base-cased')

# %%
labels = dict(zip(df.category.unique(), list(range(len(df.category.unique())))))

# %%
labels
# Out:
# {'winter_sport': 0,
#  'extreme': 1,
#  'football': 2,
#  'boardgames': 3,
#  'hockey': 4,
#  'esport': 5,
#  'athletics': 6,
#  'motosport': 7,
#  'basketball': 8,
#  'tennis': 9,
#  'autosport': 10,
#  'martial_arts': 11,
#  'volleyball': 12}

# %% [markdown]
# # Cleaning text

# %%
df[~df.index.isin(df.drop_duplicates(subset=['text']).index)]
# Out:
#              oid      category  \
# 701    763759187    basketball
# 794    340088263    boardgames
# 852    606047569    basketball
# 961    681660864  martial_arts
# 995    846465790    basketball
# ...          ...           ...
# 38678  424353857     athletics
# 38700  551674788     motosport
# 38705  508008872     athletics
# 38717  509545488        esport
# 38726  792608859    basketball
#
#                                                     text  len
# 701    За кроссовками в Баскетбольный магазин Ghetto ...   11
# 794    Коллеги традиционно объявляем очередной гильде...   51
# 852    За кроссовками в Баскетбольный магазин Ghetto ...   11
# 961    Похудеть возможно даже если. 1. Любишь сладкое...  116
# 995    За кроссовками в Баскетбольный магазин Ghetto ...   11
# ...                                                  ...  ...
# 38678  Одна из самых выгодных карт 33 Обслуживание – ...   47
# 38700  Поздравляем с днем рождения железного человека...   39
# 38705  Вакансия HR менеджер. Обязанности 1. Ознакомле...  202
# 38717  Счастливчики которые уносят Кассадина 33 За пр...   43
# 38726  За кроссовками в Баскетбольный магазин Ghetto ...   11
#
# [2966 rows x 4 columns]

# %%
pd.set_option('display.max_rows', 150)

# %%
# check for duplicates using groupby
df_nondupes = df.groupby(['text']).nunique().sort_values(by='category', ascending=False)
# find duplicates with target > 1 as a way of flagging if they are duplicate
df_dupes = df_nondupes[df_nondupes['category'] > 1]
df_dupes.rename(columns={'id':'# of duplicates', 'category':'sum of target var'})
df_dupes.sort_values('text')
# Out:
#                                                     oid  category  len
# text
# 30 дней Okko бесплатно 33 Подключайтесь и смотр...    2         2    1
# 60 дней Плюса Мульти в подарок по промокоду MYM...    4         3    1
# 60 дней Плюса Мульти в подарок по промокоду MYM...    7         4    1
# Python и Java изучаем языки программирования на...    2         2    1
# Админ здравствуйте. Пропустите или нет – не зна...    3         2    1
# Ах смотрите какой 33 Хорош правда? Брал у Васил...    2         2    1
# В связи с последними событиями многие россияне ...    7         5    1
# В условиях постоянно меняющихся цен часто прихо...    2         2    1
# Вам не нужно теперь ломать голову что подарить ...    8         5    1
# Вам не нужно теперь ломать голову что подарить ...   12         5    1
# Вам не нужно теперь ломать голову что подарить ...    4         3    1
# Водитель? Рассчитай стоимость ковриков ЭВА на с...    2         2    1
# Война в Донбассе начиналась с войны с памятника...    2         2    1
# Всероссийский центр изучения общественного мнен...    2         2    1
# Глаз не оторвать представляем дебетовую карту T...    2         2    1
# Да да это все вам. Бесплатная карта с бесплатно...    8         4    1
# Давно хотите в IT? Ищем будущих тестировщиков 3...    2         2    1
# Дважды в год каждый гражданин РФ может проверит...    2         2    1
# Дебетовая карта Ttokenoid Btokenoid Мир – это Б...    2         2    1
# Дебетовая карта Ttokenoid Drtokenoid это карта ...    3         2    1
# Дебетовая карта Тинькофф это Каждый месяц до 7 ...    2         2    1
# Дебетовая карта которая всеми силами старается ...    3         2    1
# Для тех кто хочет побеждать 33 Четыре ключа к т...    2         2    1
# Для чего нужен студенческий? Показать на входе ...    5         2    1
# Для чего нужен студенческий? Показать на входе ...    8         4    1
# Дмитрий Бивол СПАС БОКС 33 Последствия большой ...    2         2    1
# Друзья наш магазин расширяет ассортимент. Тепер...    2         2    1
# Егор возвращается в родной поселок после восьми...    3         2    1
# Желаете видеть свою рекламу здесь пишите в лс А...    4         2    1
# Желаете видеть свою рекламу здесь пишите в лс А...    4         2    1
# Желаете видеть свою рекламу здесь пишите в лс Д...    5         2    1
# Желаете видеть свою рекламу здесь пишите в лс Ж...    5         2    1
# Желаете видеть свою рекламу здесь пишите в лс И...    6         2    1
# Желаете видеть свою рекламу здесь пишите в лс И...    4         2    1
# Желаете видеть свою рекламу здесь пишите в лс И...    4         2    1
# Желаете видеть свою рекламу здесь пишите в лс И...    6         2    1
# Желаете видеть свою рекламу здесь пишите в лс К...    3         2    1
# Желаете видеть свою рекламу здесь пишите в лс М...    5         2    1
# Желаете видеть свою рекламу здесь пишите в лс Р...    3         2    1
# Желаете видеть свою рекламу здесь пишите в лс С...    4         2    1
# Желаете видеть свою рекламу здесь пишите в лс С...    2         2    1
# Желаете видеть свою рекламу здесь пишите в лс Ц...    2         2    1
# Желаете видеть свою рекламу здесь пишите в лс Ц...    2         2    1
# Желаете видеть свою рекламу здесь пишите в лс Ю...    3         2    1
# Забирай костюм для катания со скидкой 28 и допо...    4         2    1
# Забирай костюм для катания со скидкой 37 и допо...    2         2    1
# Здравствуйте 33 Взяла 28. 000 рублей на пол год...    2         2    1
# Здравствуйте админ. Пропустите или нет – не зна...    2         2    1
# Идет набор студентов в Московскую академию пред...    2         2    1
# Идет набор студентов в Московскую академию пред...    3         3    1
# Идет набор студентов в Университет Синергия 33 ...    4         3    1
# Идет набор студентов в Университет Синергия 33 ...    8         4    1
# Идет набор студентов в Университет Синергия 33 ...    2         2    1
# Идет набор студентов на медицинский факультет П...    6         3    1
# Ищем будущих разработчиков 33 Можно без опыта п...    2         2    1
# Ищу проектировщиков 33 Последний набор. Осталос...    5         2    1
# Ищу сайтоделов без опыта Лично всему научу Выхо...    2         2    1
# Ищу сайтоделов без опыта Лично всему научу Треб...    3         2    1
# КОВРИКИ ЭВА С БОРТАМИ 33 ОПЛАТА ПРИ ПОЛУЧЕНИИ В...    2         2    1
# Как вы относитесь к нововведению? Как получить ...    2         2    1
# Клуб распродаж Чики Рики 9 лет в России 33 Прис...    2         2    1
# Кэшбэк рублями а не бонусами 33 ⭐До 30 по спецп...    2         2    1
# Кэшбэк рублями а не бонусами 33 ⭐До 30 по спецп...    3         3    1
# Легендарная Финка НКВД образца 1934 года с гара...    2         2    1
# Лето уже скоро 33 Пока начать подготовку 33 Поп...    3         2    1
# Лучшие матчи Российской Премьер Лиги и Кубка Ро...    6         2    1
# Любите спорт и хотите работать с детьми чтобы п...    2         2    1
# Масштабный турнир главной кулачной лиги России ...    5         3    1
# Математика богатства и бедности Начнем с беднос...    2         2    1
# Михаил Тсамалидис Дугму Мухаммед полуфинал чемп...    2         2    1
# Мобильная связь без спама и мошенников Эта сим ...    2         2    1
# Мы ломаем все стереотипы о НАРДАХ 33 Только за ...    3         3    1
# Наколдовали вместе с художницей Настей Горшково...    3         2    1
# Напиши боту tokentokenoid узнай кого лайкает тв...    2         2    1
# Не переживайте из за вазы и своего резюме. Прих...    3         3    1
# Не так давно был утвержден закон 127 ФЗ о полно...    3         2    1
# Не только деньги 33 Выиграйте тренировку с Леон...    3         2    1
# Нужен счет для бизнеса? Оставьте заявку и получ...    4         3    1
# Нужны деньги? Напиши боту и получи деньги на ка...    3         2    1
# Нужны мужчины на проектирование загородных домо...    2         2    1
# Однажды я заказал игровой ноут MSI Motokenoid в...    2         2    1
# Одобряете безработным? ДА 33 Как получить деньг...    3         2    1
# Основы IT разработки для школьников Запишись на...    2         2    1
# Ответ всем хейтерам 33 Целый год мои курсы были...    4         3    1
# Парни почти на любую есть инфа Ссылку оставил в...    4         2    1
# Первая неделя бесплатно Мобильная связь без спа...    2         2    1
# Первый в 2022 году набор на бесплатное обучение...    3         2    1
# Плюсы быть молодым Отдыхать после пар под любим...    4         2    1
# Под покровом ночи ваши траты превратятся в кэшб...    4         2    1
# Поддержим автора репостами лайками и добавляемс...    3         2    1
# Получите 1000 ₽ на связь Дарим 1000 ₽ за перехо...    5         3    1
# Поможем зарегистрировать ИП бесплатно и перейти...    5         4    1
# Похудеть возможно даже если. 1. Любишь сладкое ...    4         2    1
# Почему Ttokenoid Btokenoid? Рассказываем о преи...    3         3    1
# Премиальный подарок мужчине 33 Шахматы и нарды ...   13         4    1
# Привет всем ️С мамой сегодня ходили в банk смот...    2         2    1
# Пройди тест за 1 минуту и получи план тренирово...    6         5    1
# Профессия тестировщик Как сделать крутую карьер...    2         2    1
# С кредитной картой TINKOFF у вас будет до 120 д...    2         2    1
# Самые риканутые карты с уникальным дизайном кэш...    3         3    1
# Сегодня долгожданная пятница 33 Желаю всем удач...    2         2    1
# Смотрите матч Спартак – Зенит на Кинопоиске. Да...    6         3    1
# Срочно возьму мужчину который ищет где бы подра...    2         2    1
# Срочно требуются IT специалисты без опыта. Всем...    2         2    1
# Столица нашей Родины и первый рубеж Победы. Бит...    2         2    1
# ТРЕБУЮТСЯ VFX дизайнер Для обучения с нуля 3П о...    2         2    1
# Тинькофф Платинум на каждый день 33 Шопинг с кэ...    6         4    1
# Тренировка Джейка Тайлера из фильма НИКОГДА НЕ ...    3         2    1
# Тссс Нужен человек который будет зарабатывать н...    2         2    1
# У кого нибудь имеется антистул? Поделитесь опыт...    2         2    1
# Увидела такой стул в ИКЕА. Кто нибудь знает как...    9         4    1
# Универсальная кредитная карта Тинькофф Платинум...    7         3    1
# Успейте оформить кредитную карту от Альфа Банка...    2         2    1
# Финальный сезон художественного сериала в основ...    3         2    1
# Финский нож Пуукко из кованной стали с обработк...    2         2    1
# Хотите получать деньги просто так? Вам карту в ...    2         2    1
# Хочешь тренироваться в 300 фитнес клубах без аб...    3         3    1
# Что НЕ замечал мир 8 лет 33 Взращивать фашизм в...    2         2    1
# Что делать если твой бизнес страдает от огранич...    2         2    1
# Что подарить женщине чтобы она вами восхищалась...    2         2    1
# Шахматы и нарды ручной работы с любым рисунком ...    5         5    1
# Это карта для игроков Wortokenoid of Tanks Btok...    3         2    1
# Это карты Рик и Морти с кэшбэком рублями до 30....    4         2    1
# Это – обложки классных альбомов а это – промоко...    2         2    1
# Этот текст может изменить вашу жизнь. Если вам ...    2         2    1
# Юридический факультет дистанционно или заочно П...    2         2    1
# Я Прыгал на Скакалке 30 Дней подряд 33 Как изме...    3         2    1
# Я Прыгал на Скакалке 60 Минут Подряд 33 Что из ...    2         2    1
# роскошная позолоченная металлическая корзина дл...    2         2    1
# ‼ТРЕБУЮТСЯ ПАРНИ Для обучения видеомонтажу Зп д...    3         2    1
# ⭐️ Защитникам Донбасса посвящается Восемь лет п...    2         2    1
# ⭐️ Работайте братья 33 Каждому бойцу необходимо...    2         2    1
# ⭐️ Я знала что наши придут. Я ждала 33 ️ 10 лет...    2         2    1
# ⭐️СБОР⭐️ Друзья мои 33 Мой близкий друг попроси...    2         2    1
# ﻿ 40 дней назад не стало Вольги командира ОТГ С...    2         2    1
# ﻿ На что пойдут США чтобы сохранить власть над ...    2         2    1
# ﻿ Правнукам. . . Традицией последних лет стал м...    2         2    1
# ﻿ ️Сергей Кургинян о том как выстаивать стране ...    2         2    1
# ﻿ ️Шутки в сторону 33 Сергей Кургинян о мобилиз...    2         2    1
# ﻿Американский педиатр разгромила гендерную теор...    2         2    1
# ﻿Пришла беда откуда не ждали? ️Государство не б...    2         2    1
# ﻿⭐️ Россия обязана победить США на Украине инач...    2         2    1
# ﻿⭐️ Учитель с большой буквы Сколько денег вклад...    2         2    1

# %%
df = df[~df.text.isin(df_dupes.reset_index().text)]
df
# Out:
#              oid      category  \
# 0      365271984  winter_sport
# 1      503385563       extreme
# 2      146016084      football
# 3      933865449    boardgames
# 4      713550145        hockey
# ...          ...           ...
# 38735  910636962     autosport
# 38736  669736851     autosport
# 38737  558919241        tennis
# 38738  776944963    volleyball
# 38739  577334983        hockey
#
#                                                     text  len
# 0      Волшебные фото Виктория Поплавская ЕвгенияМедв...    6
# 1      Возвращение в подземелье Треша 33 Эйфория тупо...   43
# 2      Лучшие чешские вратари – Доминик Доминатор Гаш...  110
# 3      Rtokenoid Warhammer40k валрак решил нас подкор...  209
# 4      Шестеркин затаскивает Рейнджерс в финал Восточ...  382
# ...                                                  ...  ...
# 38735  8 битная буря снова накрыла пикселями автомоби...   61
# 38736  Ира Сидоркова объясняет как сказалась на ее ма...   96
# 38737  24 я ракетка мира хорват Марин Чилич обыграл и...   43
# 38738  Стал известен календарь мужской сборной России...  143
# 38739  Первенство ВХЛ. Первый этап Динамо Алтай Бн ЦС...   17
#
# [38251 rows x 4 columns]

# %%
# Out:
# [nltk_data] Downloading package stopwords to /home/prop/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

def remove_html(text):
    html=re.compile(r'<.*?>')
    return html.sub(r'',text)


def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
regex = re.compile('[a-zA-Z0-9]')  # компилим regexp выражение

def preprocessing(text):
    text = regex.sub('', text)  # удаляем пунктуацию
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = remove_URL(text)
    text = remove_html(text)
    text = remove_emoji(text)
    text = [token for token in text.split()] # if token not in stop_words
    text = [token.lower() for token  in text]# Удаляем стоп слова
    # text = [stemmer.stem(token) for token in text]  # Выполняем стэмминг
    text = [token for token in text if token]
    text = [token for token in text if not 'tokenoid' in token]
    return ' '.join(text)



df['text'] = df['text'].apply(lambda x: preprocessing(x))
# Out:
# /tmp/ipykernel_6204/2895744398.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(lambda x: preprocessing(x))

# %%
df
# Out:
#              oid      category  \
# 0      365271984  winter_sport
# 1      503385563       extreme
# 2      146016084      football
# 3      933865449    boardgames
# 4      713550145        hockey
# ...          ...           ...
# 38735  910636962     autosport
# 38736  669736851     autosport
# 38737  558919241        tennis
# 38738  776944963    volleyball
# 38739  577334983        hockey
#
#                                                     text  len
# 0      волшебные фото виктория поплавская евгениямедв...    6
# 1      возвращение в подземелье треша 33 эйфория тупо...   43
# 2      лучшие чешские вратари – доминик доминатор гаш...  110
# 3      warhammer40k валрак решил нас подкормить не си...  209
# 4      шестеркин затаскивает рейнджерс в финал восточ...  382
# ...                                                  ...  ...
# 38735  8 битная буря снова накрыла пикселями автомоби...   61
# 38736  ира сидоркова объясняет как сказалась на ее ма...   96
# 38737  24 я ракетка мира хорват марин чилич обыграл и...   43
# 38738  стал известен календарь мужской сборной россии...  143
# 38739  первенство вхл. первый этап динамо алтай бн цс...   17
#
# [38251 rows x 4 columns]

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#              oid                                               text
# 0      749208109  СПОЧНО СООБЩЕСТВО ПРОДАЕТСЯ ЗА 1300Р ЗА ПОКУПК...
# 1      452466036  Естественное восстановление после тяжелой трен...
# 2      161038103  Тема нарядов продолжается Одна из британских ж...
# 3      663621910  Привет Избранный. Ты спрашиваешь себя ЧТО здес...
# 4      566255305  КОРОЛЬ ПЯТИСОТНИКОВ В ДЕЛЕ Андрей Рублев успеш...
# ...          ...                                                ...
# 26255  169728316  Выиграй коллекционный пазл по Wortokenoid of W...
# 26256  279369911  Волейбол от первого лица Егора Пупынина переко...
# 26257  600699419  Вы были когда нибудь на свидании где вам задав...
# 26258  560223506  ТОП 20 самых эффективных общефизических упражн...
# 26259  724673712  Присылайте ваши беговые фото в комментарии к э...
#
# [26260 rows x 2 columns]

# %% [markdown]
# ## train

# %%
class Dataset(torch.utils.data.Dataset):

    def __init__(self, df):

        self.labels = [labels[label] for label in df['category']]
        self.texts = [tokenizer(text, 
                               padding='max_length', max_length = 512, truncation=True,
                                return_tensors="pt") for text in df['text']]

    def classes(self):
        return self.labels

    def __len__(self):
        return len(self.labels)

    def get_batch_labels(self, idx):
        # Fetch a batch of labels
        return np.array(self.labels[idx])

    def get_batch_texts(self, idx):
        # Fetch a batch of inputs
        return self.texts[idx]

    def __getitem__(self, idx):

        batch_texts = self.get_batch_texts(idx)
        batch_y = self.get_batch_labels(idx)

        return batch_texts, batch_y

# %%
class TestDataset(torch.utils.data.Dataset):

    def __init__(self, df):

        self.oids = df['oid'].tolist()
        self.texts = [tokenizer(text, 
                               padding='max_length', max_length = 512, truncation=True,
                                return_tensors="pt") for text in df['text']]


    def __len__(self):
        return len(self.labels)

    def get_batch_oids(self, idx):
        # Fetch a batch of labels
        return np.array(self.oids[idx])

    def get_batch_texts(self, idx):
        # Fetch a batch of inputs
        return self.texts[idx]

    def __getitem__(self, idx):

        batch_texts = self.get_batch_texts(idx)
        batch_oids = self.get_batch_oids(idx)

        return batch_oids, batch_texts

# %%
class BertClassifier(nn.Module):

    def __init__(self, dropout=0.5):

        super(BertClassifier, self).__init__()

        self.bert = BertModel.from_pretrained('DeepPavlov/rubert-base-cased')
        self.dropout = nn.Dropout(dropout)
        # self.linear_1 = nn.Linear(768, 512)
        # self.relu = nn.ReLU()
        self.linear_2 = nn.Linear(768, 13)
        
        self.sigmoid = nn.Sigmoid()

    def forward(self, input_id, mask):

        _, pooled_output = self.bert(input_ids= input_id, attention_mask=mask,return_dict=False)
        dropout_output = self.dropout(pooled_output)
        
        # linear_output1 = self.linear_1(dropout_output)
        # relu_output = self.relu(linear_output1)
        linear_output2 = self.linear_2(dropout_output)
        final_layer = self.sigmoid(linear_output2)

        return final_layer

# %%
def train(model, train_data, val_data, learning_rate, epochs):

    train, val = Dataset(train_data), Dataset(val_data)

    train_dataloader = torch.utils.data.DataLoader(train, batch_size=4, shuffle=True)
    val_dataloader = torch.utils.data.DataLoader(val, batch_size=4)

    use_cuda = torch.cuda.is_available()
    # use_cuda=False
    device = torch.device("cuda" if use_cuda else "cpu")
    print('device', device)

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr= learning_rate)

    if use_cuda:

            model = model.cuda()
            criterion = criterion.cuda()

    for epoch_num in range(epochs):

            total_acc_train = 0
            total_loss_train = 0

            for train_input, train_label in tqdm(train_dataloader):

                train_label = train_label.to(device)
                mask = train_input['attention_mask'].to(device)
                input_id = train_input['input_ids'].squeeze(1).to(device)

                output = model(input_id, mask)
                
                batch_loss = criterion(output, train_label.long())
                total_loss_train += batch_loss.item()
                
                acc = (output.argmax(dim=1) == train_label).sum().item()
                total_acc_train += acc

                model.zero_grad()
                batch_loss.backward()
                optimizer.step()
            
            total_acc_val = 0
            total_loss_val = 0

            with torch.no_grad():

                for val_input, val_label in val_dataloader:

                    val_label = val_label.to(device)
                    mask = val_input['attention_mask'].to(device)
                    input_id = val_input['input_ids'].squeeze(1).to(device)

                    output = model(input_id, mask)

                    batch_loss = criterion(output, val_label.long())
                    total_loss_val += batch_loss.item()
                    
                    acc = (output.argmax(dim=1) == val_label).sum().item()
                    total_acc_val += acc
            
            print(
                f'Epochs: {epoch_num + 1} | Train Loss: {total_loss_train / len(train_data): .3f} | Train Accuracy: {total_acc_train / len(train_data): .3f} | Val Loss: {total_loss_val / len(val_data): .3f} | Val Accuracy: {total_acc_val / len(val_data): .3f}')

# %%
def evaluate(model, test_data):

    test = Dataset(test_data)

    test_dataloader = torch.utils.data.DataLoader(test, batch_size=4)

    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    if use_cuda:

        model = model.cuda()

    total_acc_test = 0
    with torch.no_grad():

        for test_input, test_label in test_dataloader:

              test_label = test_label.to(device)
              mask = test_input['attention_mask'].to(device)
              input_id = test_input['input_ids'].squeeze(1).to(device)

              output = model(input_id, mask)

              acc = (output.argmax(dim=1) == test_label).sum().item()
              total_acc_test += acc
    
    print(f'Test Accuracy: {total_acc_test / len(test_data): .3f}')

# %%
def test(model, test_data):

    test = TestDataset(test_data)

    # test_dataloader = torch.utils.data.DataLoader(test, batch_size=2)

    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    if use_cuda:

        model = model.cuda()
    
    result = []
    with torch.no_grad():

        for test_oid, test_input in test:

            test_oid = torch.from_numpy(test_oid).to(device)
            mask = test_input['attention_mask'].to(device)
            input_id = test_input['input_ids'].squeeze(1).to(device)

            output = model(input_id, mask)

            pred = output.argmax(dim=1).cpu().detach().numpy()
            max_val = output.max().item()
            result.append([test_oid.item(), pred[0], max_val])
    
    return result

# %%
np.random.seed(112)
df_train, df_val = np.split(df.sample(frac=1, random_state=58), 
                                     [int(.95*len(df))])

print(len(df_train),len(df_val))
# Out:
# 36338 1913

# %%
EPOCHS = 10
model = BertClassifier()
LR = 1e-6
              
train(model, df_train, df_val, LR, EPOCHS)
# Out:
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# device cuda
# 100%|██████████| 9085/9085 [31:25<00:00,  4.82it/s]
# Epochs: 1 | Train Loss:  0.569 | Train Accuracy:  0.505 | Val Loss:  0.527 | Val Accuracy:  0.663
# 100%|██████████| 9085/9085 [30:52<00:00,  4.90it/s]
# Epochs: 2 | Train Loss:  0.505 | Train Accuracy:  0.725 | Val Loss:  0.494 | Val Accuracy:  0.745
# 100%|██████████| 9085/9085 [30:41<00:00,  4.93it/s]
# Epochs: 3 | Train Loss:  0.478 | Train Accuracy:  0.805 | Val Loss:  0.478 | Val Accuracy:  0.784
# 100%|██████████| 9085/9085 [30:43<00:00,  4.93it/s]
# Epochs: 4 | Train Loss:  0.461 | Train Accuracy:  0.858 | Val Loss:  0.470 | Val Accuracy:  0.813
# 100%|██████████| 9085/9085 [30:46<00:00,  4.92it/s]
# Epochs: 5 | Train Loss:  0.451 | Train Accuracy:  0.893 | Val Loss:  0.465 | Val Accuracy:  0.818
# 100%|██████████| 9085/9085 [31:42<00:00,  4.78it/s]
# Epochs: 6 | Train Loss:  0.444 | Train Accuracy:  0.918 | Val Loss:  0.465 | Val Accuracy:  0.819
# 100%|██████████| 9085/9085 [31:16<00:00,  4.84it/s]
# Epochs: 7 | Train Loss:  0.440 | Train Accuracy:  0.927 | Val Loss:  0.461 | Val Accuracy:  0.841
# 100%|██████████| 9085/9085 [31:14<00:00,  4.85it/s]
# Epochs: 8 | Train Loss:  0.435 | Train Accuracy:  0.956 | Val Loss:  0.460 | Val Accuracy:  0.843
# 100%|██████████| 9085/9085 [30:54<00:00,  4.90it/s]
# Epochs: 9 | Train Loss:  0.433 | Train Accuracy:  0.965 | Val Loss:  0.459 | Val Accuracy:  0.843
# 100%|██████████| 9085/9085 [31:24<00:00,  4.82it/s]
# Epochs: 10 | Train Loss:  0.431 | Train Accuracy:  0.970 | Val Loss:  0.459 | Val Accuracy:  0.847

# %%
torch.save(model.state_dict(), './save/cleanhalf_2ep.pt')

# %%
# model.load_state_dict(torch.load('./save/cleanhalf_2ep.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Predict

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#              oid                                               text
# 0      749208109  СПОЧНО СООБЩЕСТВО ПРОДАЕТСЯ ЗА 1300Р ЗА ПОКУПК...
# 1      452466036  Естественное восстановление после тяжелой трен...
# 2      161038103  Тема нарядов продолжается Одна из британских ж...
# 3      663621910  Привет Избранный. Ты спрашиваешь себя ЧТО здес...
# 4      566255305  КОРОЛЬ ПЯТИСОТНИКОВ В ДЕЛЕ Андрей Рублев успеш...
# ...          ...                                                ...
# 26255  169728316  Выиграй коллекционный пазл по Wortokenoid of W...
# 26256  279369911  Волейбол от первого лица Егора Пупынина переко...
# 26257  600699419  Вы были когда нибудь на свидании где вам задав...
# 26258  560223506  ТОП 20 самых эффективных общефизических упражн...
# 26259  724673712  Присылайте ваши беговые фото в комментарии к э...
#
# [26260 rows x 2 columns]

# %%
df_test = df_test[~df_test.text.isin(df_dupes.reset_index().text)]
df_test
# Out:
#              oid                                               text
# 0      749208109  СПОЧНО СООБЩЕСТВО ПРОДАЕТСЯ ЗА 1300Р ЗА ПОКУПК...
# 1      452466036  Естественное восстановление после тяжелой трен...
# 2      161038103  Тема нарядов продолжается Одна из британских ж...
# 3      663621910  Привет Избранный. Ты спрашиваешь себя ЧТО здес...
# 4      566255305  КОРОЛЬ ПЯТИСОТНИКОВ В ДЕЛЕ Андрей Рублев успеш...
# ...          ...                                                ...
# 26255  169728316  Выиграй коллекционный пазл по Wortokenoid of W...
# 26256  279369911  Волейбол от первого лица Егора Пупынина переко...
# 26257  600699419  Вы были когда нибудь на свидании где вам задав...
# 26258  560223506  ТОП 20 самых эффективных общефизических упражн...
# 26259  724673712  Присылайте ваши беговые фото в комментарии к э...
#
# [26098 rows x 2 columns]

# %%
df_test['text'] = df_test['text'].apply(lambda x: preprocessing(x))
# Out:
# /tmp/ipykernel_6204/1424092570.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['text'] = df_test['text'].apply(lambda x: preprocessing(x))

# %%
df_test
# Out:
#              oid                                               text
# 0      749208109  спочно сообщество продается за 1300р за покупк...
# 1      452466036  естественное восстановление после тяжелой трен...
# 2      161038103  тема нарядов продолжается одна из британских ж...
# 3      663621910  привет избранный. ты спрашиваешь себя что здес...
# 4      566255305  король пятисотников в деле андрей рублев успеш...
# ...          ...                                                ...
# 26255  169728316  выиграй коллекционный пазл по of 33 для участи...
# 26256  279369911  волейбол от первого лица егора пупынина переко...
# 26257  600699419  вы были когда нибудь на свидании где вам задав...
# 26258  560223506  топ 20 самых эффективных общефизических упражн...
# 26259  724673712  присылайте ваши беговые фото в комментарии к э...
#
# [26098 rows x 2 columns]

# %%
pred = test(model, df_test)

# %%
pred = pd.DataFrame(pred, columns=['oid','category', 'prob'])
pred
# Out:
#              oid  category      prob
# 0      749208109        10  0.946852
# 1      452466036         7  0.925673
# 2      161038103         9  0.999033
# 3      663621910         5  0.995469
# 4      566255305         9  0.999382
# ...          ...       ...       ...
# 26093  169728316         3  0.835856
# 26094  279369911        12  0.998693
# 26095  600699419         3  0.999162
# 26096  560223506         6  0.999019
# 26097  724673712         6  0.997121
#
# [26098 rows x 3 columns]

# %%
labels_inv = {v: k for k, v in labels.items()}
labels_inv
# Out:
# {0: 'winter_sport',
#  1: 'extreme',
#  2: 'football',
#  3: 'boardgames',
#  4: 'hockey',
#  5: 'esport',
#  6: 'athletics',
#  7: 'motosport',
#  8: 'basketball',
#  9: 'tennis',
#  10: 'autosport',
#  11: 'martial_arts',
#  12: 'volleyball'}

# %%
pred['category'] = pred['category'].map(labels_inv.get)
pred
# Out:
#              oid    category      prob
# 0      749208109   autosport  0.946852
# 1      452466036   motosport  0.925673
# 2      161038103      tennis  0.999033
# 3      663621910      esport  0.995469
# 4      566255305      tennis  0.999382
# ...          ...         ...       ...
# 26093  169728316  boardgames  0.835856
# 26094  279369911  volleyball  0.998693
# 26095  600699419  boardgames  0.999162
# 26096  560223506   athletics  0.999019
# 26097  724673712   athletics  0.997121
#
# [26098 rows x 3 columns]

# %%
pred.to_csv('./output/bert_clean_output.csv')
